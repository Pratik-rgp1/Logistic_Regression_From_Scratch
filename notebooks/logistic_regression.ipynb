# %% [markdown]
# ## Building Logistic Regression Algorithm

# %%
#Load data and libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("ggplot")
# %matplotlib inline

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8

# %%
data=pd.read_csv("../data/DMV_Written_Tests.csv")
data.head()
# Out:
#    DMV_Test_1  DMV_Test_2  Results
# 0   34.623660   78.024693        0
# 1   30.286711   43.894998        0
# 2   35.847409   72.902198        0
# 3   60.182599   86.308552        1
# 4   79.032736   75.344376        1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DMV_Test_1  100 non-null    float64
#  1   DMV_Test_2  100 non-null    float64
#  2   Results     100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
# scores=data[['DMV_Test_1','DMV_Test_2']].values
# scores

# %%
# results= data[['Results']].values
# results

# %%
scores=data[['DMV_Test_1','DMV_Test_2']].values
results= data[['Results']].values

# %% [markdown]
# ### Visualize the data

# %%
# passed=(results==1).reshape(100,1)
# passed

# %%
passed=(results==1).reshape(100,1)
failed=(results==0).reshape(100,1)

ax=sns.scatterplot(x=scores[passed[:,0],0],   # select all rows        
                  y=scores[passed[:,0],1],
                  marker="^",
                  color='green',
                  s=60)
sns.scatterplot(x=scores[failed[:,0],0],   # select all rows        
                  y=scores[failed[:,0],1],
                  marker="X",
                  color='red',
                  s=60)
ax.set(xlabel="Test 1 scores",ylabel="Test 2 scores")
ax.legend(["passed","failed"])
plt.show()

# %% [markdown]
# ### Define the Logistic Sigmoid Function $\sigma(z)$
# ---
#
# $$ \sigma(z) = \frac{1}{1+e^{-z}}$$

# %%
def logistic_function(x):
    return 1/(1+np.exp(-x))

# %%
logistic_function(0)
# So, the output is 0.5 → meaning the model is uncertain — exactly 50% chance of being class 1 vs. class 0.
# Out:
# 0.5

# %% [markdown]
# ### Compute the Cost Function $J(\theta)$ and Gradient

# %% [markdown]
# The objective of logistic regression is to minimize the cost function
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^{m} [ y^{(i)}log(h_{\theta}(x^{(i)})) + (1 - y^{(i)})log(1 - (h_{\theta}(x^{(i)}))]$$
#
# where the gradient of the cost function is given by
#
# $$ \frac{\partial J(\theta)}{\partial \theta_j} = \frac{1}{m} \sum_{i=1}^{m} (h_{\theta}(x^{(i)}) - y^{(i)})x_j^{(i)}$$

# %%
def compute_cost(theta,x,y):
    m=len(y)
    y_pred=logistic_function(np.dot(x,theta))
    error=y*np.log(y_pred)+(1-y)*np.log(1-y_pred)
    
    cost=-1/m*sum(error)
    gradient=1/m*np.dot(x.transpose(),(y_pred-y))
    return cost[0],gradient

# %% [markdown]
# ### Cost and Gradient at Initialization

# %%
mean_scores=np.mean(scores,axis=0)
std_scores=np.std(scores,axis=0)
scores=(scores-mean_scores)/std_scores

rows=scores.shape[0]
cols=scores.shape[1]

#Create feature matrix X
X= np.append(np.ones((rows,1)),scores,axis=1)
y=results.reshape(rows,1)

theta_init=np.zeros((cols+1,1))
cost,gradient=compute_cost(theta_init,X,y)
print("Cost at initialization",cost)
print("Gradient at initialization",gradient)
# Out:
# Cost at initialization 0.693147180559946
# Gradient at initialization [[-0.1       ]
#  [-0.28122914]
#  [-0.25098615]]

# %% [markdown]
# ### Gradient Descent

# %% [markdown]
# Minimize the cost function $J(\theta)$ by updating the below equation and repeat until convergence
# $\theta_j := \theta_j - \alpha \frac{\partial J(\theta)}{\partial \theta_j}$ (simultaneously update $\theta_j$ for all $j$)

# %%
def gradient_descent(x,y,theta,alpha,iterations):
    costs=[]
    for i in range(iterations):
        cost,gradient = compute_cost(theta,x,y)
        theta -= (alpha*gradient)
        costs.append(cost)
    return theta,costs

# %%
theta,costs=gradient_descent(X,y,theta_init,1,200)

# %%
print("Theta after running gradient descent: ",theta)
# Out:
# Theta after running gradient descent:  [[1.50850586]
#  [3.5468762 ]
#  [3.29383709]]

# %%
print("Resulting costs: ",costs[-1])
# Out:
# Resulting costs:  0.20489382035120143

# %% [markdown]
# ### Plotting the Convergence of $J(\theta)$

# %% [markdown]
# Plot $J(\theta)$ against the number of iterations of gradient descent:

# %%
plt.plot(costs)
plt.xlabel("Iterations")
plt.ylabel("$ J(\Theta) $")
plt.title("Values of cost function over iterations of Gradient Descent")
# Out:
# Text(0.5, 1.0, 'Values of cost function over iterations of Gradient Descent')

# %% [markdown]
# ### Plotting the decision boundary

# %% [markdown]
# $h_\theta(x) = \sigma(z)$, where $\sigma$ is the logistic sigmoid function and $z = \theta^Tx$
#
# When $h_\theta(x) \geq 0.5$ the model predicts class "1":
#
# $\implies \sigma(\theta^Tx) \geq 0.5$
#
# $\implies \theta^Tx \geq 0$ predict class "1"
#
# Hence, $\theta_1 + \theta_2x_2 + \theta_3x_3 = 0$ is the equation for the decision boundary, giving us
#
# $ x_3 = \frac{-(\theta_1+\theta_2x_2)}{\theta_3}$

# %%
ax=sns.scatterplot(x=X[passed[:,0],1],   # select all rows        
                  y=X[passed[:,0],2],
                  marker="^",
                  color='green',
                  s=60)
sns.scatterplot(x=X[failed[:,0],1],   # select all rows        
                  y=X[failed[:,0],2],
                  marker="X",
                  color='red',
                  s=60)
ax.set(xlabel="DMV written Test_1 scores",ylabel="DMV written Test_2 scores")
ax.legend(["passed","failed"])

x_boundary = np.array([np.min(X[:, 1]), np.max(X[:, 1])])
y_boundary=-theta[0]+theta[1]*x_boundary/theta[2]

sns.lineplot(x=x_boundary,y=y_boundary,color="blue")
plt.show();

# %%
# # The above visualization is valid and reflects a successful logistic regression model visualization with the decision boundary.
# The blue decision boundary is separating the green and red points reasonably well.

# Students above the line are mostly "passed".

# Students below the line are mostly "failed".

# A few misclassified points are normal — logistic regression is a linear classifier, so perfect separation is not always possible, especially if the data is not linearly separable.

# %% [markdown]
# ### Predictions using the optimized $\theta$ values

# %% [markdown]
# $h_\theta(x) = x\theta$

# %%
def predict(theta,x):
    results=x.dot(theta)
    return results>0
#call the function
p=predict(theta,X)
print("Training accuracy: ",sum(p==y)[0],"%")
# Out:
# Training accuracy:  89 %

# %%
#Make prediction on unseen data
test=np.array([50,79])
test=(test-mean_scores)/std_scores
test=np.append(np.ones(1),test)
probability=logistic_function(test.dot(theta))
print("A person who scores 50 and 79 on their DMV written tests have a ",np.round(probability[0],2),"probability of passing")
# Out:
# A person who scores 50 and 79 on their DMV written tests have a  0.71 probability of passing
